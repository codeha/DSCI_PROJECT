# %%
library(repr)
library(tidyverse)
library(dplyr)
library(tidyverse)
library(tidymodels)
library(cowplot)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.
#
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp

# %%
players <-read_csv("data/players.csv") |>
select(experience, subscribe, played_hours, age)
players
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe played_hours age
# 1   Pro         TRUE     30.3          9
# 2   Veteran     TRUE      3.8         17
# 3   Veteran    FALSE      0.0         17
# 4   Amateur     TRUE      0.7         21
# 5   Regular     TRUE      0.1         21
# 6   Amateur     TRUE      0.0         17
# 7   Regular     TRUE      0.0         19
# 8   Amateur    FALSE      0.0         21
# 9   Amateur     TRUE      0.1         17
# 10  Veteran     TRUE      0.0         22
# 11  Veteran     TRUE      1.6         23
# 12  Pro         TRUE      0.0         17
# 13  Beginner    TRUE      1.5         25
# 14  Amateur     TRUE      0.2         22
# 15  Veteran     TRUE      0.0         17
# 16  Amateur    FALSE      0.0         22
# 17  Beginner    TRUE      0.0         17
# 18  Amateur     TRUE     48.4         17
# 19  Amateur     TRUE      0.5         17
# 20  Regular     TRUE      0.6         19
# 21  Regular     TRUE      0.3          8
# 22  Amateur    FALSE      0.1         17
# 23  Beginner    TRUE      1.0         17
# 24  Beginner    TRUE      0.0         17
# 25  Amateur     TRUE      0.7         21
# 26  Regular     TRUE      0.6         28
# 27  Regular     TRUE      0.0         17
# 28  Veteran    FALSE      0.0         23
# 29  Amateur     TRUE      1.8         23
# 30  Veteran    FALSE      0.1         18
# ⋮   ⋮          ⋮         ⋮            ⋮
# 167 Amateur    FALSE      1.0         26
# 168 Beginner   FALSE      0.3         17
# 169 Veteran     TRUE      0.1         17
# 170 Veteran    FALSE      0.1         17
# 171 Pro        FALSE      0.4         21
# 172 Beginner   FALSE      1.8         32
# 173 Veteran     TRUE      0.0         20
# 174 Regular    FALSE      0.0         50
# 175 Veteran     TRUE      0.0         17
# 176 Amateur     TRUE      0.3         17
# 177 Pro        FALSE      0.0         17
# 178 Veteran    FALSE      2.7         21
# 179 Amateur     TRUE      0.4         17
# 180 Veteran     TRUE      0.1         17
# 181 Amateur    FALSE      2.1         24
# 182 Amateur     TRUE      0.8         22
# 183 Pro        FALSE      0.2         17
# 184 Amateur     TRUE     32.0         22
# 185 Pro        FALSE      1.7         17
# 186 Regular    FALSE      0.1         18
# 187 Veteran     TRUE      0.1         44
# 188 Amateur     TRUE      0.0         17
# 189 Beginner    TRUE      0.0         17
# 190 Amateur    FALSE      0.0         17
# 191 Amateur     TRUE      0.0         20
# 192 Amateur     TRUE      0.0         17
# 193 Veteran    FALSE      0.3         22
# 194 Amateur    FALSE      0.0         17
# 195 Amateur    FALSE      2.3         17
# 196 Pro         TRUE      0.2         91

# %%
#data wrangling
players_renamed <- players |>
mutate(experience = recode(experience, "Beginner" = 1, "Amateur"=2, "Regular"=3, "Pro"=4, "Veteran"=5)) |>
mutate(subscribe = recode(as.character(subscribe), "FALSE"=0, "TRUE"=1))
players_renamed
# Out:
#     experience subscribe played_hours age
# 1   4          1         30.3          9
# 2   5          1          3.8         17
# 3   5          0          0.0         17
# 4   2          1          0.7         21
# 5   3          1          0.1         21
# 6   2          1          0.0         17
# 7   3          1          0.0         19
# 8   2          0          0.0         21
# 9   2          1          0.1         17
# 10  5          1          0.0         22
# 11  5          1          1.6         23
# 12  4          1          0.0         17
# 13  1          1          1.5         25
# 14  2          1          0.2         22
# 15  5          1          0.0         17
# 16  2          0          0.0         22
# 17  1          1          0.0         17
# 18  2          1         48.4         17
# 19  2          1          0.5         17
# 20  3          1          0.6         19
# 21  3          1          0.3          8
# 22  2          0          0.1         17
# 23  1          1          1.0         17
# 24  1          1          0.0         17
# 25  2          1          0.7         21
# 26  3          1          0.6         28
# 27  3          1          0.0         17
# 28  5          0          0.0         23
# 29  2          1          1.8         23
# 30  5          0          0.1         18
# ⋮   ⋮          ⋮         ⋮            ⋮
# 167 2          0          1.0         26
# 168 1          0          0.3         17
# 169 5          1          0.1         17
# 170 5          0          0.1         17
# 171 4          0          0.4         21
# 172 1          0          1.8         32
# 173 5          1          0.0         20
# 174 3          0          0.0         50
# 175 5          1          0.0         17
# 176 2          1          0.3         17
# 177 4          0          0.0         17
# 178 5          0          2.7         21
# 179 2          1          0.4         17
# 180 5          1          0.1         17
# 181 2          0          2.1         24
# 182 2          1          0.8         22
# 183 4          0          0.2         17
# 184 2          1         32.0         22
# 185 4          0          1.7         17
# 186 3          0          0.1         18
# 187 5          1          0.1         44
# 188 2          1          0.0         17
# 189 1          1          0.0         17
# 190 2          0          0.0         17
# 191 2          1          0.0         20
# 192 2          1          0.0         17
# 193 5          0          0.3         22
# 194 2          0          0.0         17
# 195 2          0          2.3         17
# 196 4          1          0.2         91

# %%
set.seed(999)
players_split2 <- initial_split(players_renamed, prop=0.7, strata = played_hours)
players_training2 <-training(players_split2)
players_testing2 <-testing(players_split2)

# %%
set.seed(999)
players_spec<- nearest_neighbor(weight_func="rectangular", neighbor=tune()) |>
set_engine ("kknn") |>
set_mode("regression")

players_recipe2 <-recipe(played_hours ~experience + subscribe + age, data = players_training2) |>
step_scale(all_predictors())|>
step_center(all_predictors())
players_recipe2
# Out:
# ── Recipe ──────────────────────────────────────────────────────────────────────
#
#
#
# ── Inputs
#
# Number of variables by role
#
# outcome:   1
# predictor: 3
#
#
#
# ── Operations
#
# • Scaling for: all_predictors()
#
# • Centering for: all_predictors()

# %%
set.seed(999)
#the neighbors2 generate a long warning message that I am not sure whether it affects final outcome.
# small folds for small data
vfold <- vfold_cv(players_training2, v=5)
grid1 <-tibble(neighbors=seq(from=1, to=10, by=1))

find_k<-workflow() |>
            add_recipe(players_recipe2) |>
            add_model(players_spec) |>
            tune_grid(resamples=vfold,grid=grid1)
findk_results<-collect_metrics(find_k)
findk_results
# Out:
#    neighbors .metric .estimator mean        n std_err    .config
# 1   1        rmse    standard   25.23275514 5 8.90896563 Preprocessor1_Model01
# 2   1        rsq     standard    0.08186810 5 0.06890360 Preprocessor1_Model01
# 3   2        rmse    standard   30.70285817 5 4.54239230 Preprocessor1_Model02
# 4   2        rsq     standard    0.09871185 5 0.05221964 Preprocessor1_Model02
# 5   3        rmse    standard   27.52394339 5 6.36610696 Preprocessor1_Model03
# 6   3        rsq     standard    0.06963202 5 0.04180848 Preprocessor1_Model03
# 7   4        rmse    standard   25.58458103 5 6.90205131 Preprocessor1_Model04
# 8   4        rsq     standard    0.05833688 5 0.03261621 Preprocessor1_Model04
# 9   5        rmse    standard   25.02272330 5 5.91357480 Preprocessor1_Model05
# 10  5        rsq     standard    0.13386703 5 0.07840563 Preprocessor1_Model05
# 11  6        rmse    standard   24.65846624 5 6.43439456 Preprocessor1_Model06
# 12  6        rsq     standard    0.08072913 5 0.05072060 Preprocessor1_Model06
# 13  7        rmse    standard   25.72943307 5 6.18087360 Preprocessor1_Model07
# 14  7        rsq     standard    0.06501230 5 0.04460949 Preprocessor1_Model07
# 15  8        rmse    standard   25.44882848 5 6.43947711 Preprocessor1_Model08
# 16  8        rsq     standard    0.06143350 5 0.03616627 Preprocessor1_Model08
# 17  9        rmse    standard   25.51853380 5 6.54064427 Preprocessor1_Model09
# 18  9        rsq     standard    0.06547474 5 0.03550266 Preprocessor1_Model09
# 19 10        rmse    standard   25.01996261 5 6.67492821 Preprocessor1_Model10
# 20 10        rsq     standard    0.06344616 5 0.03241353 Preprocessor1_Model10

# %%
set.seed(999)
best_k3<-filter(findk_results, .metric =="rmse") |>
slice_min(mean, n=1)
best_k3
# Out:
#   neighbors .metric .estimator mean     n std_err  .config
# 1 6         rmse    standard   24.65847 5 6.434395 Preprocessor1_Model06

# %%
set.seed(999)
k3 <-pull(best_k3, neighbors)

best_k_spec<-nearest_neighbor(weight_func="rectangular", neighbor=k3) |>
set_engine ("kknn") |>
set_mode("regression")

players_fit1<-workflow() |>
            add_recipe(players_recipe2) |>
            add_model(best_k_spec) |>
            fit(players_training2)

players_rmpse <- players_fit1|>
           predict(players_testing2) |>
           bind_cols(players_testing2) |>
           metrics(truth = played_hours, estimate = .pred) |>
filter(.metric=="rmse")
players_rmpse
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   30.48594

# %%
set.seed(999)
test_pred <- players_fit1|>
           predict(players_testing2) |>
           bind_cols(players_testing2) 
test_pred
# Out:
#    .pred       experience subscribe played_hours age
# 1  15.36666667 2          1           0.7        21
# 2   0.50000000 2          0           0.0        21
# 3   0.40000000 4          1           0.0        17
# 4  15.03333333 2          1           0.2        22
# 5   0.05000000 1          1           0.0        17
# 6   0.01666667 2          1           0.5        17
# 7   0.05000000 1          1           1.0        17
# 8  15.36666667 2          1           0.7        21
# 9   0.73333333 3          1           0.6        28
# 10  4.60000000 1          1           0.6        26
# 11  0.20000000 5          1           0.4        20
# 12  0.01666667 5          1           0.0        17
# 13  0.13333333 5          1           0.0        21
# 14  0.01666667 5          1           0.1        17
# 15  0.73333333 5          1          12.5        27
# 16  0.48333333 1          0           0.0        42
# 17  0.10000000 3          1           3.6        10
# 18 36.36666667 3          1           1.5        20
# 19  1.03333333 3          1         223.1        17
# 20  0.01666667 5          1           0.0        17
# 21  0.01666667 5          1           1.0        17
# 22  0.48333333 1          0           0.2        37
# 23  0.81666667 1          0           0.0        28
# 24  0.05000000 1          1           0.1        17
# 25  0.05000000 1          1           0.0        17
# 26  4.45000000 1          1           0.0        23
# 27  0.05000000 1          1           0.0        17
# 28  0.40000000 4          1           1.2        17
# 29  0.01666667 2          1           0.1        17
# 30  4.45000000 1          1           0.8        22
# 31  0.55000000 2          0           0.0        17
# 32  1.03333333 3          1           0.0        17
# 33  0.75000000 5          0           2.7        22
# 34 15.03333333 2          1           0.0        22
# 35  0.55000000 5          0           0.0        20
# 36  4.45000000 1          1           0.0        23
# 37  4.60000000 1          1           0.1        24
# 38  0.81666667 2          0           0.1        32
# 39  0.05000000 1          1           0.0        17
# 40  0.10000000 3          1          18.5        49
# 41  4.60000000 1          1           0.7        24
# 42 15.36666667 2          1           0.0        21
# 43  0.01666667 2          1           0.0        17
# 44  0.51666667 2          0           0.0        23
# 45  0.13333333 5          1           0.0        21
# 46  0.05000000 1          1           1.0        17
# 47  0.48333333 5          0           0.1        19
# 48 25.01666667 2          1           0.0        16
# 49 36.36666667 3          1           0.5        20
# 50  0.70000000 3          1           0.0        22
# 51 37.03333333 3          1           0.1        21
# 52  1.20000000 1          0           0.3        17
# 53  0.83333333 4          0           0.4        21
# 54  0.20000000 5          1           0.0        20
# 55  0.01666667 5          1           0.0        17
# 56  0.01666667 5          1           0.1        17
# 57 15.03333333 2          1           0.8        22
# 58  0.16666667 3          0           0.1        18
# 59  0.01666667 2          1           0.0        17
# 60  6.01666667 2          1           0.0        20
